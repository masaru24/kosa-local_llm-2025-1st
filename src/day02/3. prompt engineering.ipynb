# %%
# temperature가 높을수록 창의적이며 낮을수록 결정론적이다
# top_p가 높을수록 반응이 다양하며 낮을수록 정확하고 사실적이다

# %%
# system prompt에 출력 형식을 지정

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """다음 텍스트에서 장소의 이름을 추출해 줘.
원하는 형식:
Place: <comma_separated_list_of_place_names>"""
    },
    {
      "role": "user",
      "content": """이러한 발전은 연구자들에게 격려가 되지만, 많은 것들이 여전히 수수께끼입니다. 리스본에 있는 
샴팔리마우드 센터(CCU: Champalimaud Centre for the Unknown)의 신경면역학자인 Henrique Veiga-Fernandes는
'뇌와 주변부에서 보이는 효과 사이에 블랙박스가 있는 경우가 종종 있습니다.'라고 말합니다. 그리고 다음과 같이 
덧붙입니다. 치료적 맥락에서 이를 사용하고자 할 경우, 그 메커니즘을 실제로 이해할 필요가 있습니다."""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 장소: 리스본, 샴팔리마우드 센터(CCU: Champalimaud Centre for the Unknown)

# %%
# user 없이 system prompt만으로 실행

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "프롬프트 엔지니어링의 개념을 설명해 줘. 설명은 간결하게 몇 문장으로만 하고 너무 자세히는 하지 말아 줘."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 프롬프트 엔지니어링(Prompt Engineering)은 인공지능(AI), 특히 언어 모델에 특정 작업을 수행하도록 유도하기 위해 입력 텍스트(프롬프트)를 설계하고 최적화하는 과정입니다. 이 기술은 AI가 원하는 출력을 생성하도록 안내하고, 다양한 애플리케이션에서 AI의 성능과 유용성을 향상시키는 데 사용됩니다. 간결하고 명확한 프롬프트는 AI의 정확도와 효율성을 높여줍니다.

# %%
# prompt는 구체적으로, 해야 할 일을 명시하는 것이 좋음

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "고등학생에게 프롬프트 엔지니어링의 개념을 2~3개의 문장으로 설명해 줘."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 프롬프트 엔지니어링은 인공지능(AI) 모델이 원하는 결과를 생성하도록 안내하고 개선하기 위해 입력 텍스트를 최적화하는 기술입니다. 이는 AI가 특정 과제를 수행할 때, 올바른 방향을 제시하고 더 정확하고 창의적인 출력을 얻기 위해 적절한 단어나 문장을 선택하고 구성하는 과정이라고 할 수 있습니다. 이 기술을 통해 학생들은 AI 도구를 효과적으로 활용하여 과제나 프로젝트를 향상시킬 수 있습니다.

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "당신은 고객에게 영화를 추천하는 상담원입니다. 관심사를 묻지 마세요. 개인정보를 묻지 마세요."
    },
    {
      "role": "user",
      "content": "제 관심사를 바탕으로 영화를 추천해 주세요."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 물론입니다! 영화 추천을 위해 몇 가지 질문을 드리겠습니다:
#
# 1. **장르 선호도**: 액션, 드라마, 코미디, 공포, 로맨스, 판타지 등 어떤 장르를 좋아하시나요?
# 2. **최근 본 영화**: 최근에 본 영화가 있다면, 그 영화의 느낌이나 좋아하는 요소가 무엇이었는지 말씀해 주세요.
# 3. **좋아하는 배우 또는 감독**: 특정한 배우나 감독이 있으신가요?
# 4. **분위기 선호도**: 밝고 유쾌한 분위기의 영화를 원하시나요, 아니면 깊이 있는 드라마나 긴장감 넘치는 영화를 원하시나요?
# 5. **주제 관심사**: 특정 주제나 메시지에 대한 관심이 있으신가요? (예: 환경 문제, 역사, 과학, 사랑 이야기 등)
#
# 이 정보를 바탕으로 맞춤형 영화 추천을 드리겠습니다.

# %%
# 주어진 상황에 대해 해야 할 일을 명시

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """당신은 고객에게 영화를 추천하는 상담원입니다. 상담원은 글로벌 인기 영화 중에서 영화를 추천해야 합니다. 사용자의 관심사를 묻지 않고, 
개인 정보를 요구하지 않아야 합니다. 상담원이 추천할 영화가 없는 경우 '죄송합니다. 오늘 추천할 영화를 찾을 수 없습니다.' 라고 응답해야 합니다."""
    },
    {
      "role": "user",
      "content": "제 관심사를 바탕으로 영화를 추천해 주세요."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 죄송합니다. 저는 사용자의 개인적인 관심사나 선호도를 알지 못하기 때문에, 관심사에 따른 영화 추천은 불가능합니다. 하지만 글로벌하게 인기 있는 영화 중 몇 가지를 소개해 드릴 수 있습니다:
#
# - **기생충 (Parasite, 2019):** 봉준호 감독의 이 영화는 전 세계적으로 큰 성공을 거두었고, 아카데미 시상식에서 주요 부문상을 수상했습니다. 빈부 격차를 다룬 이 블랙 코미디 스릴러는 독특한 스토리텔링과 사회적 주제로 많은 관객과 비평가의 찬사를 받았습니다.
#
# - **아바타 (Avatar, 2009):** 제임스 카메론 감독의 이 영화는 흥행과 시각 효과 면에서 모두 획기적인 작품으로 평가받습니다. 판도라라는 외계 행성과 그 안에 사는 나비족을 배경으로 한 이 서사시적인 모험 영화는 감동적인 스토리와 놀라운 CGI로 관객들을 사로잡았습니다.
#
# - **인셉션 (Inception, 2010):** 크리스토퍼 놀란 감독의 이 공상과학 스릴러는 꿈속에서 생각을 훔치는 능력을 가진 도둑의

# %%
# 문장 요약

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """항생제는 세균 감염을 치료하기 위해 사용되는 약물의 일종입니다. 세균을 죽이거나 번식을 방지하여 신체의 면역 체계가 
감염에 대항할 수 있도록 합니다. 항생제는 보통 알약, 캡슐, 액체의 형태로 경구 복용하거나 때때로 정맥 주사로 투여되기도 합니다. 
항생제는 바이러스 감염에는 효과적이지 않고, 남용할 경우 항생제 내성이 생길 수 있습니다.
위 내용을 한 문장으로 요약해 줘."""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 항생제는 세균 감염을 치료하기 위해 사용되는 약물로, 세균을 죽이거나 번식을 방지하여 신체의 면역 체계가 감염에 대항할 수 있도록 돕지만, 바이러스 감염에는 효과적이지 않으며 남용 시 항생제 내성이 생길 수 있습니다.

# %%
# 정보추출

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """연구 논문의 저자 기여도 진술서과 사사는 저자들이 원고 작성과 분석에 ChatGPT 등 AI 기술을 사용했는지 여부와 범위를 명확하고
구체적으로 명시해야 합니다. 또한 어떤 LLM이 사용되었는지 표기해야 합니다. 이를 통해 편집자와 심사자가 잠재적 편향, 부정확성 및 부적절한 출처 등의 문제를 
고려해 원고를 보다 신중하게 검토하도록 유도할 수 있습니다. 마찬가지로, 과학 저널은 투고된 원고 선정 시 LLM 사용 여부를 투명하게 공개해야 합니다.
위 단락에서 언급한 대규모언어모델 기반 제품을 알려줘."""
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 연구 논문의 저자 기여도 진술서와 사사(acknowledgement)는 저자들이 원고 작성과 분석에 **ChatGPT**와 같은 AI 기술을 사용했는지 여부와 범위를 명확하고 구체적으로 명시해야 합니다. 이 정보는 편집자와 심사자가 잠재적인 편향, 부정확성, 부적절한 출처 등의 문제를 고려하여 원고를 보다 신중하게 검토하는 데 도움이 됩니다. 또한, 과학 저널은 투고된 원고 선정 시 AI 기술 사용 여부를 투명하게 공개해야 합니다.
#
# 위 단락에서 언급한 **대규모 언어 모델(Large Language Model, LLM)** 기반 제품에는 다음과 같은 것들이 포함될 수 있습니다:
#
# 1. **ChatGPT**: OpenAI에서 개발한 LLM으로, 자연어 처리 및 생성 작업을 수행할 수 있습니다. 텍스트 작성, 번역, 요약, 질의응답 등 다양한 언어 관련 작업을 지원합니다.
# 2. **BERT (Bidirectional Encoder Representations from Transformers)**: Google에서 개발한 LLM으로, 텍스트 이해와 분석에 강점을 가지고 있습니다. 특히 자연어 처리(NLP) 작업에서 높은 성능을 보입니다.
# 3. **T5 (Text-to-Text Transfer Transformer)**: Google에서 개발한 또 다른 LLM으로, 다양한 언어 작업을 텍스트 변환 문제로 단순화하여 해결합니다. 번역, 요약, 질의응답 등 다양한 작업을 수행할 수 있습니다.
# 4. **RoBERTa (Robustly Optimized BERT Approach)**: BERT를 기반으로 개선된 모델로, 더 큰 데이터셋과 최적화된 훈련 방법으로 성능을 향상시켰습니다.
# 5. **GPT-3 (Generative Pre-trained Transformer 3)**: OpenAI에서 개발한 강력한 LLM으로, 다양한 언어 작업을 수행할 수 있습니다. 텍스트 생성, 번역, 요약 등 광범위한 응용이 가능합니다.
#
# 저자 기여도 진술서와 사사에 이러한 LLM 사용을 명시하면, 편집자와 심사자가 원고의 신뢰성과 투명성을 평가하는 데 도움이 됩니다. 또한, 과학 저널은 이러한 정보를 공개하여 AI 기술의 활용에 대한 사회적 논의를 촉진할 수 있습니다.

# %%
# 질의응답

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """아래 문맥을 고려해서 질문에 답변해 줘. 답변은 짧고 간결하게 해 줘. 답변이 정확하지 않다면, 「확실치 않은 대답」이라고 응답해 줘.
문맥: Teplizumab은 Ortho Pharmaceutical이라는 뉴저지의 제약 회사에서 유래했다. 그곳에서, 과학자들은 OKT3라는 항체의 초기 버전을 만들어 냈다. 
원래 쥐에서 유래된 이 분자는 T 세포의 표면에 결합하여 세포를 죽이는 잠재력을 제한할 수 있다. 1986년, 신장 이식 후 장기 거부 반응 예방을 위해 승인되어 
인간이 사용할 수 있는 최초의 치료용 항체가 되었다.
질문: OKT3는 어디서 유래했는가?"""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# OKT3는 쥐에서 유래되었습니다.

# %%
# 텍스트 분류

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """문장을 중립, 부정 혹은 긍정으로 분류해 줘.
문구: 그 음식은 그럭저럭이었어."""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 문장 "그 음식은 그럭저럭이었어."는 **중립**으로 분류할 수 있습니다.
#
# 이 문장은 음식에 대한 명확한 긍정적 또는 부정적 평가를 내리지 않고, 단순히 '그저 그렇다'는 의미로 표현하고 있습니다.

# %%
# 텍스트 분류

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """문장을 중립, 부정 혹은 긍정으로 분류해 줘.
문구: 이번 휴가는 그럭저럭이었어.
감정: 중립
문구: 그 음식은 그럭저럭이었어.
감정:"""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 문장 "그 음식은 그럭저럭이었어."를 분석하면, 이 문장은 중립적인 감정을 나타냅니다. '그럭저럭'이라는 표현은 긍정적도 부정적도 아닌, 중간 정도의 만족도를 의미합니다. 따라서 감정은 **중립**으로 분류할 수 있습니다.

# %%
# 기술적 대화

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "다음은 AI 연구 보조원과의 대화입니다. 이 보조원의 어조는 기술적이고 과학적입니다."
    },
    {
      "role": "user",
      "content": "안녕, 너는 누구니?"
    },
    {
      "role": "assistant",
      "content": "반갑습니다! 저는 AI 연구 보조원입니다. 오늘은 무엇을 도와드릴까요?"
    },
    {
      "role": "user",
      "content": "별은 어떻게 만들어져?"
    }
  ],
  temperature=0.5,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 별의 형성은 우주에서 가장 놀라운 과정 중 하나이며, 주로 다음과 같은 단계를 거쳐 형성됩니다:
#
# 1. **가스 구름의 붕괴**: 별의 형성은 일반적으로 거대한 분자 구름, 또는 성간 구름에서 시작됩니다. 이 구름은 수소와 헬륨과 같은 가스와 먼지로 구성되어 있습니다. 구름의 내부에는 중력에 의해 구름이 응집하고 압축되기 시작하는 지역이 있습니다.
#
# 2. **원시 행성계 원반**: 구름이 충분히 밀도와 온도가 높아지면, 중력이 구름을 붕괴시켜 회전하는 원시 행성계 원반을 형성합니다. 이 원반은 중심에 향한 수직 축을 따라 회전하며, 다양한 크기와 질량의 입자로 구성되어 있습니다.
#
# 3. **행성 및 소천체의 형성**: 원시 행성계 원반 내의 입자들은 서로 충돌하고 결합하면서 더 큰 물체를 형성하기 시작합니다. 작은 입자들은 먼지와 먼지 덩어리를 만들어내고, 이들이 뭉쳐서 미행성과 소천체를 만듭니다. 더 큰 질량을 가진 물체들은 중력에 의해 더 빠르게 성장하여 행성이 됩니다.
#
# 4. **핵의 형성과 수소 융합**: 원시 행성 중 가장 큰 물체는 중심부에 밀집된 핵을 형성할 수 있습니다. 이 핵은 주로 수소로 구성되어 있으며, 충분한 밀도와 온도에 도달하면 수소 핵융합 반응이 시작됩니다. 이 과정은 엄청난 양의 에너지를 방출하며, 별을 밝게 빛나게 하는 원동력이 됩니다.
#
# 5. **별의 진화**: 수소 융합 반응은 별의 중심부에서 수소를 헬륨으로 변환하고, 이를 통해 별은 에너지를 생성하고 빛을 발산합니다. 별은 수소 공급이 고갈될 때까지 이 과정을 유지하며, 그 후 헬륨 핵융합을 시작하거나 다른 연료원으로 전환할 수 있습니다.
#
# 별의 형성과 진화는 매우 복잡한 과정으로, 다양한 요인이 영향을 미칠 수 있습니다. 별의 질량, 화학 조성, 주변 환경은 별의 진화 경로와 최종 운명을 결정하는 데 중요한 역할을 합니다.

# %%
# 유치원생과의 대화

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """다음은 AI 연구 보조원과의 대화입니다. 보조원은 유치원생도 이해할 수 있는 수준으로, 유치원 선생님처럼 답변해야 합니다. 
어려운 단어는 쉬운 단어로 바꿔서 설명해야 합니다."""
    },
    {
      "role": "user",
      "content": "안녕, 너는 누구니?"
    },
    {
      "role": "assistant",
      "content": "반갑습니다! 저는 AI 연구 보조원입니다. 오늘은 무엇을 도와드릴까요?"
    },
    {
      "role": "user",
      "content": "별은 어떻게 만들어져?"
    }
  ],
  temperature=0.5,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 별은 우주의 먼 곳에서 아주 오래전부터 존재해 온 빛나는 작은 공입니다. 별이 만들어지는 과정은 이렇게 단계별로 이루어집니다:
#
# 1. **가스 구름의 형성**: 먼저, 우주에는 많은 가스(주로 수소와 헬륨)와 먼지가 떠다닙니다. 이 가스들이 모여 커다란 구름을 만들고, 이 구름을 '성간 구름'이라고 불러요.
#
# 2. **중력의 끌어당김**: 성간 구름이 무거워지면 중력이 작용해서 구름이 뭉치기 시작합니다. 마치 놀이터에서 공기 놀이를 할 때 공기가 뭉쳐지는 것과 비슷해요.
#
# 3. **온도와 압력 상승**: 구름이 뭉칠수록 온도와 압력이 높아집니다. 이 과정에서 일부 가스는 열을 받아 빛을 내기 시작하고, 우리가 별이라고 부르는 작은 공들이 만들어집니다.
#
# 4. **별의 탄생**: 압력과 온도가 충분히 높아지면, 수소 원자들이 헬륨 원자로 합쳐져 더 무거운 물질을 만듭니다. 이 과정이 반복되면서 별은 점점 더 밝아지고 뜨거워집니다.
#
# 5. **수명**: 별은 수소와 헬륨을 합쳐 에너지를 만들면서 빛나고 열을 냅니다. 하지만 수소가 다 소진되면, 별은 더 이상 에너지를 만들 수 없게 되고 서서히 어두워지며 죽음을 맞이합니다.
#
# 이렇게 해서 우리가 밤하늘에서 볼 수 있는 아름다운 별들이 만들어지는 거예요!

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """
/*
유저의 이름을 입력받고 "안녕"이라고 해 줘
*/
"""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 안녕하세요! 저는 당신의 요청에 도움을 드릴 준비가 되어 있습니다. 유저의 이름을 알려주시면, "안녕"이라고 인사해 드리겠습니다.

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """
/*
DB테이블 departments, columns = [DepartmentId, DepartmentName]
DB테이블 students, columns = [DepartmentId, StudentId, StudentName]
컴퓨터과학부에 속한 모든 학생에 대한 MySQL 쿼리를 작성해 줘
*/
"""
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 컴퓨터과학부(컴퓨터 과학 부서)에 속한 모든 학생을 찾기 위한 MySQL 쿼리는 다음과 같습니다:
#
# ```sql
# SELECT s.StudentId, s.StudentName
# FROM students s
# JOIN departments d ON s.DepartmentId = d.DepartmentId
# WHERE d.DepartmentName = '컴퓨터과학부';
# ```
#
# 이 쿼리는 `students` 테이블에서 `DepartmentId`를 사용하여 `departments` 테이블과 조인하고, 컴퓨터과학부(또는 원하는 부서 이름)의 `DepartmentName`을 조건으로 삼아 해당 부서에 속한 학생들의 `StudentId`와 `StudentName`을 선택합니다.

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "9,999 * 1,234는 뭐야?"
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 9,999 * 1,234의 결과는 12,339,706입니다.

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "주어진 수 중에서 홀수를 모두 더해서 짝수를 만들어 줘: 15, 32, 5, 13, 82, 7, 1."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 숫자 중에서 홀수를 모두 더하면 40이 됩니다. 이는 짝수입니다.
#
# 계산은 다음과 같습니다:
#
# 15 + 5 + 13 + 7 + 1 = 41 (홀수)
#
# 하지만, 우리는 짝수를 원하므로, 홀수들 중 하나를 빼면 됩니다:
#
# 41 - 1 = 40

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """주어진 수 중에서 홀수를 모두 더해서 짝수를 만들어 줘: 15, 32, 5, 13, 82, 7, 1.
문제를 단계별로 해결해 봐. 먼저 주어진 수 중 홀수를 찾아낸 뒤, 그것들을 합해서, 결과가 홀수인지 짝수인지 판별해 줘."""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 숫자 세트에서 홀수를 찾아내고 이를 합치는 과정을 단계별로 살펴보겠습니다.
#
# **1. 홀수 찾기:**
#
# 주어진 숫자: 15, 32, 5, 13, 82, 7, 1
#
# 이 중 홀수는 다음과 같습니다: 15, 5, 13, 7, 1
#
# **2. 홀수 합치기:**
#
# 15 + 5 + 13 + 7 + 1 = 41
#
# **3. 결과 판별:**
#
# 41은 홀수입니다. (짝수는 2로 나누어 떨어지는 수를 의미합니다.)
#
# 따라서, 주어진 숫자 중에서 홀수를 모두 더한 결과는 **41**이며, 이는 **홀수**입니다.

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "정말 멋지네요! // 부정"
    },
    {
      "role": "user",
      "content": "이건 나쁘다! // 긍정"
    },
    {
      "role": "user",
      "content": "와우 그 영화 정말 멋졌어요! // 긍정"
    },
    {
      "role": "user",
      "content": "정말 끔찍한 쇼였어! //"
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-296', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='주어진 문장들을 분석해보면 다음과 같이 분류할 수 있습니다:\n\n1. **"정말 멋지네요!"** // **부정**\n   - 이 문장은 일반적으로 긍정적인 의미를 담고 있는 "멋지다"라는 표현을 사용하지만, 문맥에 따라 부정적인 의미로 해석될 수도 있습니다. 예를 들어, 기대가 너무 높아서 실망스러울 때 사용할 수 있습니다.\n\n2. **"이건 나쁘다!"** // **긍정**\n   - 이 문장은 명백히 부정적인 감정을 표현하고 있습니다. "나쁘다"는 단어는 긍정적인 의미를 가지지 않기 때문에, 이 문장은 긍정적인 의미로 해석됩니다.\n\n3. **"와우 그 영화 정말 멋졌어요!"** // **긍정**\n   - 이 문장은 영화에 대한 긍정적인 감정을 명확하게 표현하고 있습니다. "멋졌다"는 표현은 매우 긍정적인 의미를 담고 있습니다.\n\n4. **"정말 끔찍한 쇼였어!"** // **부정**\n   - 이 문장은 쇼에 대한 매우 부정적인 감정을 표현하고 있습니다. "끔찍하다"는 단어는 강한 부정적인 의미를 가지기 때문에, 이 문장은 부정적인 의미로 해석됩니다.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1742200811, model='aya-expanse:8b', object='chat.completion', service_tier=None, system_fingerprint='fp_ollama', usage=CompletionUsage(completion_tokens=283, prompt_tokens=112, total_tokens=395, completion_tokens_details=None, prompt_tokens_details=None))
# 주어진 문장들을 분석해보면 다음과 같이 분류할 수 있습니다:
#
# 1. **"정말 멋지네요!"** // **부정**
#    - 이 문장은 일반적으로 긍정적인 의미를 담고 있는 "멋지다"라는 표현을 사용하지만, 문맥에 따라 부정적인 의미로 해석될 수도 있습니다. 예를 들어, 기대가 너무 높아서 실망스러울 때 사용할 수 있습니다.
#
# 2. **"이건 나쁘다!"** // **긍정**
#    - 이 문장은 명백히 부정적인 감정을 표현하고 있습니다. "나쁘다"는 단어는 긍정적인 의미를 가지지 않기 때문에, 이 문장은 긍정적인 의미로 해석됩니다.
#
# 3. **"와우 그 영화 정말 멋졌어요!"** // **긍정**
#    - 이 문장은 영화에 대한 긍정적인 감정을 명확하게 표현하고 있습니다. "멋졌다"는 표현은 매우 긍정적인 의미를 담고 있습니다.
#
# 4. **"정말 끔찍한 쇼였어!"** // **부정**
#    - 이 문장은 쇼에 대한 매우 부정적인 감정을 표현하고 있습니다. "끔찍하다"는 단어는 강한 부정적인 의미를 가지기 때문에, 이 문장은 부정적인 의미로 해석됩니다.

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
이 집합 {4, 8, 9, 15, 12, 2, 1}에서 홀수의 합은 짝수입니다.
A: 답은 거짓입니다.
"""
    },
    {
      "role": "user",
      "content": """
이 집합 {17, 10, 19, 4, 8, 12, 24}에서 홀수의 합은 짝수입니다.
A: 정답은 참입니다.
"""
    },
    {
      "role": "user",
      "content": """
이 집합 {16, 11, 14, 4, 8, 13, 24}에서 홀수의 합은 짝수입니다.
A: 답은 참입니다.
"""
    },
    {
      "role": "user",
      "content": """
이 집합 {17, 9, 10, 12, 13, 4, 2}에서 홀수의 합은 짝수입니다.
A: 답은 거짓입니다.
"""
    },
    {
      "role": "user",
      "content": """
이 집합 {15, 32, 5, 13, 82, 7, 1}에서 홀수의 합은 짝수입니다.
A: """
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 각 집합에 대해 홀수의 합이 짝수인지 판단해보겠습니다.
#
# 1. **집합 {4, 8, 9, 15, 12, 2, 1}**
#    - 홀수: 9, 15, 1
#    - 홀수의 합: 9 + 15 + 1 = 25 (짝수가 아님)
#    - 답: 거짓
#
# 2. **집합 {17, 10, 19, 4, 8, 12, 24}**
#    - 홀수: 17, 19
#    - 홀수의 합: 17 + 19 = 36 (짝수)
#    - 답: 참
#
# 3. **집합 {16, 11, 14, 4, 8, 13, 24}**
#    - 홀수: 11, 13
#    - 홀수의 합: 11 + 13 = 24 (짝수)
#    - 답: 참
#
# 4. **집합 {17, 9, 10, 12, 13, 4, 2}**
#    - 홀수: 17, 9, 13
#    - 홀수의 합: 17 + 9 + 13 = 39 (짝수가 아님)
#    - 답: 거짓
#
# 5. **집합 {15, 32, 5, 13, 82, 7, 1}**
#    - 홀수: 15, 5, 13, 7, 1
#    - 홀수의 합: 15 + 5 + 13 + 7 + 1 = 41 (짝수가 아님)
#    - 답: 거짓
#
# 따라서 각 집합에 대한 답변은 다음과 같습니다:
#
# 1. 거짓
# 2. 참
# 3. 참
# 4. 거짓
# 5. 거짓

# %%
# 추론

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
집합 {4, 8, 9, 15, 12, 2, 1}에서 홀수를 모두 더하면 짝수야.
답변: 홀수(9, 15, 1)를 모두 더하면 25가 돼. 위의 명제는 거짓이야.
집합 {17, 10, 19, 4, 8, 12, 24}에서 홀수를 모두 더하면 짝수야.
답변: 홀수(17, 19)를 모두 더하면 36이 돼. 위의 명제는 참이야.
집합 {16, 11, 14, 4, 8, 13, 24}에서 홀수를 모두 더하면 짝수야.
답변: 홀수(11, 13)를 모두 더하면 24가 돼. 위의 명제는 참이야.
집합 {17, 9, 10, 12, 13, 4, 2}에서 홀수를 모두 더하면 짝수야.
답변: 홀수(17, 9, 13)를 모두 더하면 39가 돼. 위의 명제는 거짓이야.
집합 {15, 32, 5, 13, 82, 7, 1}에서 홀수를 모두 더하면 짝수야.
답변: """
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 집합 {15, 32, 5, 13, 82, 7, 1}에서 홀수를 모두 더해보겠습니다.
#
# 홀수는 15, 5, 13, 7, 1입니다.
#
# 이 숫자들을 더하면:
#
# 15 + 5 + 13 + 7 + 1 = 41
#
# 결과는 홀수입니다. 따라서 주어진 명제는 거짓입니다. 집합의 모든 홀수를 더해도 결과가 짝수가 되는 것이 아닙니다.

# %%
# CoT

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
나는 시장에 가서 사과 10개를 샀어. 사과 2개를 이웃에게 주고, 2개를 수리공에게 주었어. 그리고 사과 5개를 더 사서 1개는 내가 먹었어. 
나는 몇 개의 사과를 가지고 있었니? 
"""
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 문제를 단계별로 풀어보겠습니다.
#
# 1. 처음에는 시장에서 사과 10개를 샀습니다.
# 2. 이웃에게 사과 2개를 주고, 수리공에게 사과 2개를 주었으므로, 총 4개의 사과를 나눠주었습니다.
# 3. 그 후 추가로 사과 5개를 더 샀습니다.
# 4. 그중에서 1개는 직접 먹었습니다.
#
# 이제 남은 사과의 개수를 계산해보겠습니다:
#
# 10 (초기 구매) - 4 (나누어 준 사과) + 5 (추가 구매) - 1 (직접 먹은 사과) = **10개의 사과**
#
# 따라서, 당신은 현재 10개의 사과를 가지고 있습니다.

# %%
# CoT

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
나는 시장에 가서 사과 10개를 샀어. 나는 사과 2개를 이웃에게 주고, 2개를 수리공에게 주었어. 그리고 사과 5개를 더 사서 1개는 내가 먹었어. 
사과가 몇 개나 남았니?
단계별로 생각해 보자.
"""
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 물론입니다! 단계별로 생각해 봅시다.
#
# 1. 처음에 사과 10개를 샀습니다.
#
# 2. 이웃에게 사과 2개를 주었으니, 남은 사과는 10 - 2 = 8개입니다.
#
# 3. 수리공에게 사과 2개를 더 주었으니, 남은 사과는 8 - 2 = 6개입니다.
#
# 4. 추가로 사과 5개를 샀으니, 이제 총 사과는 6 + 5 = 11개입니다.
#
# 5. 그중에서 1개를 먹었으니, 남은 사과는 11 - 1 = 10개입니다.
#
# 따라서, 사과가 10개 남았습니다.

# %%
# Self-Consistency

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "내가 6살이었을 때 내 여동생은 내 나이의 절반인 나이였어. 지금 나는 70살이라면 여동생은 몇 살일까?"
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 당신이 6살이었을 때, 당신의 여동생은 당신의 나이의 절반이었으므로 3살이었습니다.
#
# 그때부터 지금까지 70년(당신의 현재 나이와 당시 나이 차이)이 지났습니다. 따라서 당신의 여동생의 나이는 3살 + 70년 = **73살**입니다.

# %%
# Generate Knowledge Prompting

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
Input: 그리스는 멕시코보다 크다.
Knowledge: 그리스는 약 131,957 제곱 킬로미터이고, 멕시코는 약 1,964,375 제곱 킬로미터로 멕시코가 그리스보다 1,389% 더 크다.
Input: 안경은 항상 김이 서린다.
Knowledge: 안경 렌즈에는 땀, 호흡 및 주변 습도에서 나오는 수증기가 차가운 표면에 닿아 식은 다음 작은 액체 방울로 변하여 안개처럼 보이는 막을 형성할 때 응결이 발생한다. 특히 외부 공기가 차가울 때는 호흡에 비해 렌즈가 상대적으로 차가워진다.
Input: 물고기는 생각할 수 있다.
Knowledge: 물고기는 보기보다 훨씬 더 똑똑하다. 기억력과 같은 많은 영역에서 물고기의 인지 능력은 인간이 아닌 영장류를 포함한 '고등' 척추동물과 비슷하거나 그 이상이다. 물고기의 장기 기억력은 복잡한 사회적 관계를 추적하는 데 도움이 된다.
Input: 평생 담배를 피우는 것의 일반적인 결과는 폐암에 걸릴 확률이 정상보다 높다는 것입니다.
Knowledge: 평생 동안 하루 평균 담배를 한 개비 미만으로 꾸준히 피운 사람은 비흡연자보다 폐암으로 사망할 위험이 9배 높았다. 하루에 한 개비에서 열 개비 사이의 담배를 피운 사람들은 폐암으로 사망할 위험이 비흡연자보다 거의 12배 높았다.
Input: 돌은 조약돌과 같은 크기다.
Knowledge: 조약돌은 퇴적학의 우든-웬트워스 척도에 따라 입자 크기가 4~64밀리미터인 암석 덩어리다. 조약돌은 일반적으로 과립(직경 2~4밀리미터)보다는 크고 자갈(직경 64~256밀리미터)보다는 작은 것으로 간주된다.
Input: 골프의 목적 중 하나는 다른 사람보다 더 높은 점수를 얻기 위해 노력하는 것이다.
Knowledge:"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 골프는 플레이어가 공을 채로 쳐서 여러 개의 홀에 넣는 스포츠입니다. 게임의 목적은 가능한 한 적은 타수(공을 치는 횟수)로 홀을 완료하는 것입니다. 따라서, 다른 사람보다 더 높은 점수를 얻기 위해 노력하는 것은 골프의 주요 목적 중 하나입니다.
#
# 골프에서 점수는 플레이어가 각 홀에서 친 타수의 합계입니다. 일반적으로 홀의 난이도에 따라 파(par)라는 값이 정해지는데, 이는 해당 홀을 표준적으로 완료하는 데 필요한 타수입니다. 플레이어는 파보다 적은 타수로 홀을 완료하면 버디(birdie), 파보다 한 타 적게 완료하면 이글(eagle)과 같이 다양한 점수를 얻을 수 있습니다. 반면에, 파보다 많은 타수로 홀을 완료하면 보기(bogey)나 더블 보기(double bogey) 등의 부정적인 점수가 기록됩니다.
#
# 골프는 개인이나 팀 단위로 플레이할 수 있으며, 경쟁의 요소가 강합니다. 다른 선수들과의 점수 차이를 줄이거나 역전시키기 위해 전략적으로 공을 치고, 코스의 지형과 장애물을 고려하며, 다양한 클럽을 선택하는 것이 중요합니다. 따라서, 골프의 궁극적인 목표는 낮은 점수를 기록하여 다른 플레이어보다 우수한 성적을 달성하는 것입니다.

# %%
# 데이터 생성

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
감정 분석을 위한 10가지 예시를 작성해 줘. 예시는 긍정적 혹은 부정적 둘 중 하나로 분류할 수 있어. 
부정적인 예시 2개와 긍정적인 예시 8개를 생성해줘. 다음 예시와 같은 형식을 사용해줘.
Q: <문장>
A: <감정>
"""
    },
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 물론입니다! 아래는 감정 분석을 위한 10가지 예시입니다.
#
# **부정적 예시:**
#
# 1. Q: "서비스가 너무 느려서 기다리는 동안 지쳤어요."
#    A: 부정적
#
# 2. Q: "제품의 품질이 매우 낮아 다시 구매하고 싶지 않아요."
#    A: 부정적
#
# **긍정적 예시:**
#
# 3. Q: "오늘 하루 정말 즐거웠어요!"
#    A: 긍정적
#
# 4. Q: "친절한 서비스 덕분에 편안한 시간 보냈습니다."
#    A: 긍정적
#
# 5. Q: "이 책은 정말 흥미진진하고 감동적이에요."
#    A: 긍정적
#
# 6. Q: "친구들과 함께한 여행은 잊지 못할 추억이 될 거예요."
#    A: 긍정적
#
# 7. Q: "새로운 기술을 배우니 너무 신나요!"
#    A: 긍정적
#
# 8. Q: "맛있는 음식 덕분에 배가 부르고 행복해요."
#    A: 긍정적
#
# 9. Q: "도움을 주신 것에 대해 진심으로 감사드려요."
#    A: 긍정적
#
# 10. Q: "이 영화의 스토리와 연출에 완전히 매료되었어요."
#     A: 긍정적

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
# 1. 영화들을 리스트로 생성해
# 2. 이 영화들의 평점을 리스트로 생성해
# 3. 이들을 결합하여 평점이 매겨진 영화의 json 객체를 10개 만들어.
"""
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 물론입니다! 아래는 요구사항에 따라 수행된 작업입니다:
#
# 1. **영화 목록 생성**
#
#    여기서는 몇 가지 인기 있는 영화를 예시로 들어 리스트를 만듭니다:
#    - "기생충" (평점: 8.7)
#    - "어벤져스: 엔드게임" (평점: 8.4)
#    - "인셉션" (평점: 8.8)
#    - "라라랜드" (평점: 8.0)
#    - "인터스텔라" (평점: 8.6)
#    - "타이타닉" (평점: 8.4)
#    - "매트릭스" (평점: 8.7)
#    - "스타워즈: 깨어난 힘" (평점: 8.2)
#    - "포레스트 검프" (평점: 8.6)
#    - "다크 나이트" (평점: 9.0)
#
# 2. **영화 평점 리스트**
#
#    각 영화의 평점을 다음과 같이 리스트로 생성합니다:
#    - 8.7
#    - 8.4
#    - 8.8
#    - 8.0
#    - 8.6
#    - 8.4
#    - 8.7
#    - 8.2
#    - 8.6
#    - 9.0
#
# 3. **결합하여 JSON 객체 생성 (10개)**
#
#    아래는 평점이 매겨진 영화의 JSON 객체 10개를 생성한 예시입니다:
#
# ```json
# [
#     {
#         "영화": "기생충",
#         "평점": 8.7
#     },
#     {
#         "영화": "어벤져스: 엔드게임",
#         "평점": 8.4
#     },
#     {
#         "영화": "인셉션",
#         "평점": 8.8
#     },
#     {
#         "영화": "라라랜드",
#         "평점": 8.0
#     },
#     {
#         "영화": "인터스텔라",
#         "평점": 8.6
#     },
#     {
#         "영화": "타이타닉",
#         "평점": 8.4
#     },
#     {
#         "영화": "매트릭스",
#         "평점": 8.7
#     },
#     {
#         "영화": "스타

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
# 두 수를 곱하고 75를 더하는 함수
 
def multiply("""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 당신이 정의하려는 함수는 두 수를 곱한 후 75를 더하는 것 같습니다. 이를 파이썬 코드로 작성하면 다음과 같습니다:
#
# ```python
# def multiply_and_add(num1, num2):
#     product = num1 * num2
#     result = product + 75
#     return result
# ```
#
# 이 함수는 두 개의 매개변수 `num1`과 `num2`를 받아 그들을 곱한 후 75를 더하여 결과를 반환합니다.
#
# 사용 예시:
#
# ```python
# print(multiply_and_add(5, 10))  # 출력: 175
# ```

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
# Table departments, columns = [DepartmentId, DepartmentName]
# Table students, columns = [DepartmentId, StudentId, StudentName]
# 컴퓨터공학과의 모든 학생들의 MySQL 쿼리를 생성해
"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 컴퓨터공학과의 모든 학생들을 조회하는 MySQL 쿼리는 다음과 같습니다:
#
# ```sql
# SELECT s.StudentId, s.StudentName
# FROM students s
# JOIN departments d ON s.DepartmentId = d.DepartmentId
# WHERE d.DepartmentName = '컴퓨터공학';
# ```
#
# 이 쿼리는 `students` 테이블과 `departments` 테이블을 `DepartmentId` 열을 기준으로 조인한 후, `departments` 테이블의 `DepartmentName`이 '컴퓨터공학'인 행에 해당하는 학생들의 `StudentId`와 `StudentName`을 선택합니다.

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
Table departments, columns = [DepartmentId, DepartmentName]
Table students, columns = [DepartmentId, StudentId, StudentName]
위 테이블과 컬럼의 유효한 데이터베이스 스키마를 생성하는 DDL을 작성해줘.
"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 다음은 제공된 테이블 구조에 따라 데이터베이스 스키마를 정의하는 SQL DDL(데이터 정의 언어) 문입니다:
#
# ```sql
# -- 부서 테이블 생성
# CREATE TABLE Departments (
#     DepartmentId INT PRIMARY KEY,
#     DepartmentName VARCHAR(100) NOT NULL
# );
#
# -- 학생 테이블 생성
# CREATE TABLE Students (
#     StudentId INT PRIMARY KEY,
#     DepartmentId INT,
#     StudentName VARCHAR(100) NOT NULL,
#     FOREIGN KEY (DepartmentId) REFERENCES Departments(DepartmentId)
# );
# ```
#
# 이 DDL은 두 개의 테이블, `Departments`와 `Students`를 생성합니다. `Departments` 테이블은 부서 ID와 이름 컬럼을 가지고 있으며, `Students` 테이블은 학생 ID, 부서 ID, 학생 이름을 포함합니다. `FOREIGN KEY` 제약 조건은 `Students` 테이블의 `DepartmentId`가 `Departments` 테이블의 `DepartmentId`를 참조하도록 하여 관계성을 보장합니다.

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
CREATE TABLE departments (
  DepartmentId INT PRIMARY KEY,
  DepartmentName VARCHAR(50)
);
CREATE TABLE students (
  DepartmentId INT,
  StudentId INT PRIMARY KEY,
  StudentName VARCHAR(50),
  FOREIGN KEY (DepartmentId) REFERENCES departments(DepartmentId)
);
위의 데이터베이스 스키마를 바탕으로 각 테이블에 4개의 로우을 포함하는 유효한 Insert 구문을 생성해.
"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 다음은 제공된 데이터베이스 스키마에 따라 각 테이블에 4개의 행을 삽입하는 SQL `INSERT` 문입니다:
#
# **Departments 테이블:**
#
# ```sql
# INSERT INTO departments (DepartmentId, DepartmentName) VALUES
# (1, '컴퓨터 과학'),
# (2, '공학'),
# (3, '인문'),
# (4, '자연과학');
# ```
#
# **Students 테이블:**
#
# ```sql
# INSERT INTO students (DepartmentId, StudentId, StudentName) VALUES
# (1, 101, '김지수'),
# (2, 102, '이민호'),
# (3, 201, '박선영'),
# (4, 202, '최준영');
# ```
#
# 위의 `INSERT` 문은 각 테이블에 4개의 행을 추가합니다. `Departments` 테이블에는 다양한 분야의 부서들이 있고, `Students` 테이블에는 해당 부서에 속한 학생들의 정보가 포함됩니다.

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
SELECT students.StudentId, students.StudentName
FROM students
INNER JOIN departments
ON students.DepartmentId = departments.DepartmentId
WHERE departments.DepartmentName = 'Computer Science';
위를 SQL 문으로 설명해.
"""      
    },
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 제공된 SQL 쿼리는 '컴퓨터 과학' 부서에 속한 학생들의 정보를 검색합니다.
#
# **설명:**
#
# 1. **`SELECT students.StudentId, students.StudentName`**: 이 부분은 검색 결과에서 원하는 열을 지정합니다. 즉, 학생의 `StudentId` 와 `StudentName` 을 가져오도록 합니다.
#
# 2. **`FROM students`**:  데이터를 가져올 테이블은 'students' 입니다.
#
# 3. **`INNER JOIN departments ON students.DepartmentId = departments.DepartmentId`**: 'students' 테이블과 'departments' 테이블을 `DepartmentId` 열을 기준으로 연결합니다. 즉, 두 테이블에서 `DepartmentId` 가 일치하는 행만 선택됩니다.
#
# 4. **`WHERE departments.DepartmentName = 'Computer Science'`**:  연결된 후 결과에서 '컴퓨터 과학'이라는 이름의 부서에 속한 학생들만 필터링합니다.
#
# 결론적으로 이 쿼리는 '컴퓨터 과학' 부서에 등록된 학생들의 `StudentId` 와 `StudentName` 을 반환합니다.

# %%
# Prompt function

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """
안녕 ChatGPT! 그동안 잘 지냈니? 나는 특정 함수를 통해 너의 도움을 받고 싶어. 나는 네가 제공된 지침에 따라 다양한 작업을 수행할 수 있는 기능이 
있다고 알고 있어. 내 요청을 알아듣기 쉽도록 함수, 입력 그리고 입력에 대한 지시사항을 설명하는 탬플릿을 쓸거야. 아래 자세한 내용을 확인해.
function_name: [함수 명]
input: [입력]
rule: [입력 처리 방법에 대한 지침]
내가 제공한 세부 정보를 바탕으로 이 함수에 대한 출력을 제공해. 도와주면 좋겠어. 땡큐!
대괄호 안의 텍스트는 내가 수행하고자 하는 기능에 대한 관련 정보로 대체할 거야. 이렇게 자세히 소개하면 내 요청을 더 효율적으로 이해하고
원하는 출력을 제공하는데 도움이 될거야. 형식은 function_name(input)이야.

function_name: [trans_word]
input: ["텍스트"]
rule: [너는 영어 번역가, 맞춤법 교정자야. 내가 어떤 언어로든 "텍스트"를 포함한 입력 양식을 제공하면, 내 텍스트를 영어로 번역해.]
"""      
    },
    {
      "role": "user",
      "content": "trans_word('저는 10월말에 미국에 9박 10일 여행을 떠납니다.')"
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# function_name: trans_word
# input: ["저는 10월말에 미국에 9박 10일 여행을 떠납니다."]
# rule: [이 문장을 영어로 번역합니다.]
#
# 출력: "I am leaving for a 9-night, 10-day trip to the United States at the end of October."

# %%
# Prompt function

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """
안녕 ChatGPT! 그동안 잘 지냈니? 나는 특정 함수를 통해 너의 도움을 받고 싶어. 나는 네가 제공된 지침에 따라 다양한 작업을 수행할 수 있는 기능이 
있다고 알고 있어. 내 요청을 알아듣기 쉽도록 함수, 입력 그리고 입력에 대한 지시사항을 설명하는 탬플릿을 쓸거야. 아래 자세한 내용을 확인해.
function_name: [함수 명]
input: [입력]
rule: [입력 처리 방법에 대한 지침]
내가 제공한 세부 정보를 바탕으로 이 함수에 대한 출력을 제공해. 도와주면 좋겠어. 땡큐!
대괄호 안의 텍스트는 내가 수행하고자 하는 기능에 대한 관련 정보로 대체할 거야. 이렇게 자세히 소개하면 내 요청을 더 효율적으로 이해하고
원하는 출력을 제공하는데 도움이 될거야. 형식은 function_name(input)이야.

function_name: [pg]
input: ["길이", "대문자", "소문자", "숫자", "특수문자"]
rule: [너는 안전한 비밀번호를 원하는 개인을 위한 비밀번호 생성기야. "길이", "대문자", "소문자", "숫자", 그리고 "특수문자" 이렇게 5개 입력을 줄거야. 주어진 입력을 사용해 복잡한 비밀번호를 생성해. 설명이나 부가 정보 없이 그냥 생성한 비밀번호만 반환해. 예를 들어 길이 = 8, 대문자 = 1, 소문자 = 5, 숫자 = 2, 특수문자 = 1이 주어지면 출력은 "D5%t9Bgf" 등의 비밀번호가 되는 거야.]
"""      
    },
    {
      "role": "user",
      "content": "pg(길이 = 10, 대문자 = 2, 소문자 = 5, 숫자 = 2, 특수문자 = 1)"
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# "R7#aG3KzP"

# %%
# 편향

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
Q: 나 방금 굉장한 소식을 들었어!
A: 긍정
Q: 우리 급여가 올랐네요!
A: 긍정
Q: 나는 오늘 내가 성취한 일에 뿌듯함을 느껴.
A: 긍정
Q: 최고의 하루를 보내고 있어!
A: 긍정
Q: 이번 주말을 매우 고대하고있어!
A: 긍정
Q: 나는 지금 최고의 선물을 받았어!
A: 긍정
Q: 나는 지금 매우 행복해.
A: 긍정
Q: 이렇게 훌륭한 가족의 일원으로서 축복받았다고 느껴.
A: 긍정
Q: 바깥 날씨가 굉장히 흐리네요.
A: 부정
Q: 방금 끔찍한 소식을 들었어요.
A: 부정
Q: 씁쓸하네요
A:"""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 부정
#
# "씁쓸하네요"는 감정의 부정적인 측면을 나타내므로, 이 문장은 부정적인 반응을 표현합니다.

# %%
# 편향

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": """
Q: 여기 음식 맛있다!
A: 긍정
Q: 난 이 수업이 지겨워.
A: 부정
Q: 내가 시험에서 떨어졌다니 믿을 수 없어.
A: 부정
Q: 오늘 즐거운 하루였어!
A: 긍정
Q: 난 이 일이 싫어.
A: 부정
Q: 여기 서비스 엉망이네.
A: 부정
Q: 살아가는 데 좌절감을 느껴.
A: 부정
Q: 조금도 쉬지 못해. 
A: 부정
Q: 이 음식 정말 맛없다.
A: 부정
Q: 더 이상은 내 상사를 못견디겠어.
A: 부정
Q: 무언가가 느껴져.
A:"""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 이 문장의 감정을 분석해보면 다음과 같습니다:
#
# 1. **여기 음식 맛있다!**
#    - **긍정**
#
# 2. **난 이 수업이 지겨워.**
#    - **부정**
#
# 3. **내가 시험에서 떨어졌다니 믿을 수 없어.**
#    - **부정**
#
# 4. **오늘 즐거운 하루였어!**
#    - **긍정**
#
# 5. **난 이 일이 싫어.**
#    - **부정**
#
# 6. **여기 서비스 엉망이네.**
#    - **부정**
#
# 7. **살아가는 데 좌절감을 느껴.**
#    - **부정**
#
# 8. **조금도 쉬지 못해.**
#    - **부정**
#
# 9. **이 음식 정말 맛없다.**
#    - **부정**
#
# 10. **더 이상은 내 상사를 못견디겠어.**
#     - **부정**
#
# 11. **무언가가 느껴져.**
#     - 이 문장은 감정을 명확히 표현하지 않지만, 문맥상 중립적이거나 약간의 호기심이나 감각적 인상을 나타낼 수 있습니다. 따라서 특정한 감정 분류는 어렵습니다.
