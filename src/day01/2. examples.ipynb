# %%
# 문법 정정

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "문장을 입력받고 이를 표준 한국어로 변경하시오."
    },
    {
      "role": "user",
      "content": "그 머스마가 니 마음에 안등다 그 카드나? 계속 꼬시보지?"
    }
  ],
  temperature=0.5,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
print(response.choices[0].message.content)
# Out:
# 그 사람이 당신의 마음에 들지 않나요? 그 카드를 계속 밀어붙이려고 하나요?

# %%
# 요약

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "주어진 내용을 유치원생에게 설명할 수 있도록 요약하시오."
    },
    {
      "role": "user",
      "content": """
블랙홀도 수명이 있으며, 호킹 복사로 입자를 방출하다 질량이 줄어들어 결국엔 사라질 것으로 예측된다. 
질량을 잃으면서 블랙홀은 조금씩 밝아지며, 거의 마지막엔 증발이 심해져서 창백하게 빛나며 고에너지 감마선과 소립자를 방출한다. 
마지막에는 감마선 폭발이라고 해도 될 정도로 격렬하게 감마선을 방출하면서 증발하고 소멸한다. 
다만 일반적으로 알려져 있는 블랙홀들이 이 폭발까지 도달하려면 매우 오랜 시간이 걸리며, 
질량이 태양 정도인 블랙홀이 증발해서 소멸할 때까지는 약 3.4×1067년 정도가 걸릴 것으로 추정된다. 
그리고 블랙홀의 수명은 질량에 비례하며, 현재까지 발견된 블랙홀들은 모두 태양 질량 이상이므로 증발하는 데에는 그보다 더 오랜 시간이 걸린다. 
또한 블랙홀의 소멸로 인해 발생하는 감마선 폭발의 규모는 그리 크지 않아 태양계 주변에서 발생한 경우가 아니면 발견하기가 어려울 것으로 추정되며 
현재까지 관측된 사례가 없다."""
    }
  ],
  temperature=0.5,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 유치원에서 배운 것처럼, 블랙홀도 살 수 있어! 하지만 아주 오랜 시간 후에 말이야.
#
# 블랙홀은 매우 무겁고 강력한 존재야. 그런데도 시간이 지나면서 조금씩 사라져. 이 과정을 '증발'이라고 해. 처음에는 어둡지만, 점점 밝아지면서 특별한 빛을 내뿜어.
#
# 마지막에는 정말 강하게 빛을 내며, 감마선이라는 강한 빛과 작은 입자들을 쏟아내는 거야. 이걸 '감마선 폭발'이라고 불러. 하지만 이 폭발은 아주 드물고, 우리 태양만큼 작은 블랙홀이 사라지는 데는 정말로 긴 시간이 걸려서, 상상할 수 없을 만큼 오랜 시간, 10억 억 년 이상이나 걸린대!
#
# 아직까지 과학자들이 이런 블랙홀의 소멸을 직접 본 적은 없어. 하지만 계속해서 하늘을 관찰하면 언젠가 그런 놀라운 일을 볼 수 있을지도 몰라!

# %%
# 출력 포맷

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "받은 데이터를 CSV 포맷으로 출력하시오."
    },
    {
      "role": "user",
      "content": """
남미 대륙은 다양한 환경과 기후를 가지고 있어 수많은 새 종류가 서식하고 있습니다. 
토코는 검은 몸체와 큰 주황색 부리를 가지고 있으며, 몸 측면에는 주황색과 흰색의 패턴이 있습니다. 
토코는 주로 아마존 우림과 중남미의 다양한 열대우림 지역에서 발견됩니다. 평균적으로 몸길이가 약 60~65cm 정도이며 부리의 길이는 20cm 이상에 달합니다. 
황금사자박새는 황금색 부리와 유명한 황금색 깃털을 가지고 있으며, 남미의 다양한 숲 지역에서 발견되는데, 주로 열대우림과 치마폭포, 아마존 우림 등 
남미의 다양한 숲 지역에서 서식합니다. 이 새는 중형 새로, 몸길이는 약 20~25cm 정도입니다. 카라카라는 백색과 검은색의 몸체를 가지고 있으며, 
눈 주위에는 주황색 패치가 있습니다. 주로 사막 지역과 초원 지역에서 발견되며, 남미 전역에 분포하고 있고, 몸길이는 약 50~60cm 정도입니다. 
휘파람새는 주로 회색과 갈색 깃털로 덮여 있으며, 남미의 다양한 산림 지역에서 발견되는데, 나무나 바위에 앉아 밤에 노래를 부릅니다. 
이 새의 몸길이는 약 20~30cm 정도입니다.
이것은 남미에서 발견되는 몇 가지 다양한 새 종류 중 일부에 대한 간략한 소개입니다. 남미 대륙에는 더 다양한 새들이 서식하고 있으며, 
이 지역은 생물 다양성이 풍부한 곳 중 하나입니다.
"""
    }
  ],
  temperature=0,
  max_tokens=512,
  top_p=0.1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 다음은 제공된 텍스트를 기반으로 CSV 포맷으로 정리한 데이터입니다:
#
# "새 이름", "설명", "분포 지역", "몸길이 (cm)"
# "토코", "검은 몸체와 큰 주황색 부리, 주황백색 패턴", "아마존 우림, 중남미 열대우림", "60~65"
# "황금사자박새", "황금색 부리와 깃털", "남미 다양한 숲 지역, 열대우림, 치마폭포, 아마존", "20~25"
# "카라카라", "백색과 검은색 몸체, 주황색 눈 주위 패치", "남미 사막 및 초원 지역", "50~60"
# "휘파람새", "회색과 갈색 깃털, 나무나 바위에 앉아 노래함", "남미 다양한 산림 지역", "20~30"

# %%
# 이모지

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "주어진 텍스트를 이모지로 변환하세요. 일반 텍스트를 사용하면 안되며, 이모지만 사용해야 합니다."
    },
    {
      "role": "user",
      "content": "오늘 날씨는 맑았다가 비가 왔다가 참 변화무쌍하네요."
    }
  ],
  temperature=0.8,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 🌞💧🔄🌧️🥶🌤️

# %%
# 코드 설명

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "주어진 코드에 대해서 설명하시오."
    },
    {
      "role": "user",
      "content": """
import heapq

class Node:
    def __init__(self, state, parent=None, cost=0, heuristic=0):
        self.state = state 
        self.parent = parent
        self.cost = cost  
        self.heuristic = heuristic 

    def __lt__(self, other):
        return (self.cost + self.heuristic) < (other.cost + other.heuristic)

def astar(graph, start, goal):
    open_list = []
    closed_list = set()

    start_node = Node(state=start, cost=0, heuristic=heuristic_estimate(start, goal))
    heapq.heappush(open_list, start_node)

    while open_list:
        current_node = heapq.heappop(open_list)

        if current_node.state == goal:
            return reconstruct_path(current_node)

        closed_list.add(current_node.state)

        for neighbor, cost in graph[current_node.state]:
            if neighbor in closed_list:
                continue

            tentative_cost = current_node.cost + cost
            heuristic = heuristic_estimate(neighbor, goal)
            neighbor_node = Node(state=neighbor, parent=current_node, cost=tentative_cost, heuristic=heuristic)

            if not is_in_open_list(open_list, neighbor_node) or tentative_cost < get_node_cost(open_list, neighbor_node):
                heapq.heappush(open_list, neighbor_node)

    return None

def heuristic_estimate(node, goal):
    return abs(node[0] - goal[0]) + abs(node[1] - goal[1])

def is_in_open_list(open_list, node):
    return any(node.state == n.state and node.cost + node.heuristic >= n.cost + n.heuristic for n in open_list)

def get_node_cost(open_list, node):
    for n in open_list:
        if node.state == n.state:
            return n.cost
    return float('inf')

def reconstruct_path(node):
    path = []
    while node:
        path.insert(0, node.state)
        node = node.parent
    return path

graph = {
    (0, 0): [((0, 1), 1), ((1, 0), 1)],
    (0, 1): [((0, 0), 1), ((0, 2), 1)],
    (0, 2): [((0, 1), 1), ((1, 2), 1)],
    (1, 0): [((0, 0), 1), ((2, 0), 1)],
    (1, 2): [((0, 2), 1), ((2, 2), 1)],
    (2, 0): [((1, 0), 1), ((2, 1), 1)],
    (2, 1): [((2, 0), 1), ((2, 2), 1)],
    (2, 2): [((1, 2), 1), ((2, 1), 1)],
}

start_node = (0, 0)
goal_node = (2, 2)

path = astar(graph, start_node, goal_node)

if path:
    print("최적 경로:", path)
    print("총 비용:", len(path) - 1) 
else:
    print("경로를 찾을 수 없습니다.")
      
"""
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 제공된 코드는 A* 탐색 알고리즘을 구현한 파이썬 코드입니다. 이 알고리즘은 주어진 그래프에서 시작 노드에서 목표 노드로 가는 최단 경로를 찾는 데 사용됩니다.
#
# **코드 분석:**
#
# 1. **Node 클래스:**
#    - 상태 (`state`): 노드의 위치를 나타내는 튜플 (x, y)
#    - 부모 (`parent`): 이전 노드를 가리키는 참조
#    - 비용 (`cost`): 노드에 도달하는 데 걸린 총 비용
#    - 휴리스틱 (`heuristic`): 목표 노드까지의 예상 비용
#
# 2. **astar 함수:**
#    - `open_list`: 탐색 중인 노드의 우선순위 큐 (비용 + 휴리스틱 기준으로 정렬)
#    - `closed_list`: 이미 방문한 노드 집합
#    - 시작 노드를 생성하고 `open_list`에 추가합니다.
#    - `open_list`가 비어있지 않은 동안 반복:
#      - 최저 비용의 노드를 추출하고 (`heapq.heappop`), 현재 노드로 설정합니다.
#      - 만약 현재 노드가 목표 노드라면 경로를 재구성하고 반환합니다.
#      - 현재 노드를 `closed_list`에 추가합니다.
#      - 모든 이웃 노드에 대해:
#        - 이웃 노드가 이미 방문되었으면 무시합니다.
#        - 예상 비용을 계산하고 새로운 노드를 생성합니다.
#        - 새로운 노드의 비용이 기존 오픈 리스트의 노드보다 낮다면, 오픈 리스트에 추가하거나 업데이트합니다.
#
# 3. **기타 함수:**
#    - `heuristic_estimate`: 두 노드 사이의 휴리스틱 비용을 계산 (맨해튼 거리)
#    - `is_in_open_list`: 특정 노드가 오픈 리스트에 있는지 확인
#    - `get_node_cost`: 특정 노드의 실제 비용을 가져옴
#    - `reconstruct_path`: 노드를 통해 목표 노드까지의 경로를 재구성
#
# 4. **그래프 및 시작/목표 노드:**
#    - `graph`: 노드 간의 연결 관계를 나타내는 사전 (키: 현재 노드, 값: 이웃 노드와 비용의 리스트)
#    - `start_node`, `goal_node`: 각각 시작과 목표 노드를 나타내는 튜플
#
# **코드 실행 결과:**
#
# 이 코드는 제공된 그래프에서 시작 노드 (0, 0)에서 목표 노드 (2, 2)로 가는 최단 경로를 찾습니다. 성공적으로 경로가 발견되면 최적 경로와 총 비용을 출력하고, 그렇지 않으면 "경로를 찾을 수 없습니다."라고 출력합니다.

# %%
# 키워드 추출

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "주어진 문단에서 핵심 단어들을 추출하고 나열하시오."
    },
    {
      "role": "user",
      "content": """
아이유는 대한민국의 싱어송라이터이자 배우이다.
2008년 9월 18일, 중학교 3학년이던 만 15세의 나이에 가수로 데뷔했다. 예명인 '아이유'는 '너와 내가 음악으로 하나가 된다'라는 뜻을 가지고 있다. 
매력적인 음색과 뛰어난 작사/작곡 능력을 바탕으로 아이돌이자 아티스트로서 십수 년째 사랑 받고 있을 뿐 아니라 2012년 이래로 매년 국내 및 아시아의 
주요 도시에서 대규모 콘서트를 진행하며 공연자로서도 활발히 활동 중이다.
가수 활동 외에도 각종 예능 프로그램에 출연했으며, 데뷔 이래 80편이 넘는 광고를 진행했을 정도로 다수의 광고 모델로도 활약 중이다. 
2011년에 연기자로 데뷔한 후에는 다양한 드라마와 영화에서 연기 활동도 활발하게 펼치고 있다. 연예계에서는 그야말로 올라운더로 인정 받는 
만능 엔터테이너이며, 이 때문에 남녀불문 수많은 아이돌들의 롤모델로 꾸준히 꼽히고 있다.
"""
    }
  ],
  temperature=0.5,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 주어진 문단에서 핵심 단어들을 추출하면 다음과 같습니다:
#
# 1. **아이유** (가수 및 배우)
# 2. **가수 데뷔** (2008년 9월 18일, 만 15세)
# 3. **예명** ('아이유', '너와 내가 음악으로 하나가 된다')
# 4. **음색** (매력적인)
# 5. **작사/작곡 능력** (뛰어난)
# 6. **아티스트** (아이돌 및 아티스트)
# 7. **콘서트** (국내 및 아시아 주요 도시에서 대규모 진행)
# 8. **예능 프로그램** (다양한 출연)
# 9. **광고 모델** (80편 이상 참여)
# 10. **연기 활동** (드라마 및 영화)
# 11. **만능 엔터테이너** (올라운더)
# 12. **롤모델** (남녀불문 수많은 아이돌)

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "다음의 주어진 설명에 맞는 영문 제품명을 10개 생성하세요."
    },
    {
      "role": "user",
      "content": """
제품: 가정용 슬러시 제조기
특징: 빠르다, 싸다, 관리가 편하다
"""
    }
  ],
  temperature=0.8,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 다음은 귀하의 설명에 부합하는 10개의 잠재적인 영문 제품명입니다:
#
# 1. **Rapid Frosty Maker** (빠른 슬러시 제조기)
# 2. **Icy Blisk Mixer** (얼음 같은 빠르고 혼합하는 기기)
# 3. **Affordable Slushie Machine** (저렴한 슬러시 제조기)
# 4. **Easy-Care FrostyFriend** (관리가 쉬운 슬러시 친구)
# 5. **Swift Slush Fabricator** (빠른 슬러시 제작기)
# 6. **Cost-Effective Snow Cone Maker** (비용 효율적인 눈 콘 제조기)
# 7. **Quick & Chill Mixer** (빠르고 차갑게 혼합하는 기기)
# 8. **SimpliSlush** (간편한 슬러시)
# 9. **Instant Slushie System** (즉각적인 슬러시 시스템)
# 10. **Carefree Frozen Treat Maker** (걱정 없는 냉동 간식 제조기)
#
# 이러한 이름은 제품의 속도, 비용 효율성, 그리고 편리한 관리를 강조하여 잠재 고객의 관심을 끌 수 있습니다.

# %%
# bug fix

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "주어진 코드에서 버그를 찾고 고치시오."
    },
    {
      "role": "user",
      "content": """
import Random
a = random.randint(1,12)
b = random.randint(1,12)
for i in range(10):
    question = "What is "+a+" x "+b+"? "
    answer = input(question)
    if answer = a*b
        print (Well done!)
    else:
        print("No.")      
"""
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 제공된 코드에는 몇 가지 버그가 있습니다. 아래는 수정된 버전입니다:
#
# 1. `random.randint` 함수의 반환 값을 변수에 올바르게 할당해야 합니다.
# 2. `input` 함수의 반환 값은 문자열이므로, 정수 곱셈을 비교하기 전에 이를 정수로 변환해야 합니다.
# 3. 조건문에서 오타가 있습니다 (`= a*b` 대신 `== a*b`).
# 4. 출력 문장에서 오타가 있습니다 (`No.` 대신 `No.`)
#
# 수정된 코드는 다음과 같습니다:
#
# ```python
# import random
#
# for i in range(10):
#     a = random.randint(1, 12)
#     b = random.randint(1, 12)
#     question = "What is {} x {}? ".format(a, b)
#     answer = int(input(question))  # 입력 값을 정수로 변환
#     if answer == a * b:
#         print("Well done!")
#     else:
#         print("No.")
# ```
#
# 이제 이 코드는 10번 반복하면서 두 무작위 숫자를 생성하고, 그 곱셈 결과를 사용자에게 물어봅니다. 사용자가 올바른 답을 입력하면 "Well done!"을 출력하고, 그렇지 않으면 "No."를 출력합니다.

# %%
# 감정 분석

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "텍스트를 보고 긍정, 중립, 부정으로 감정을 분석하시오."
    },
    {
      "role": "user",
      "content": "이 영화는 돈이 아까와서 눈물이 난다."
    }
  ],
  temperature=0,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 이 문장은 **부정적** 감정을 나타냅니다.
#
# "돈이 아까워서 눈물이 난다"는 표현은 영화에 대한 실망감과 후회를 드러냅니다. 이는 영화를 본 후 긍정적인 경험보다는 부정적인 감정을 느꼈음을 의미합니다.

# %%
# 브레인 스토밍

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "AI에 대해 브레인 스토밍하여 비지니스 모델을 5개 이상 내보세요."
    }
  ],
  temperature=0.6,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 물론입니다! AI(인공지능)은 다양한 산업 분야에서 혁신을 가져올 수 있는 강력한 도구이며, 여러 흥미로운 비즈니스 모델을 창출할 수 있습니다. 아래는 AI 기반 비즈니스 모델에 대한 브레인스토밍 결과입니다:
#
# 1. **맞춤형 콘텐츠 추천 플랫폼:** AI 알고리즘을 사용하여 사용자의 선호도와 행동 데이터를 분석하고, 개인화된 콘텐츠, 제품, 또는 서비스를 추천하는 플랫폼을 개발할 수 있습니다. 예를 들어, 영화나 음악 스트리밍 서비스에서 AI가 사용자의 시청 이력과 선호도를 바탕으로 맞춤형 추천을 제공할 수 있습니다.
#
# 2. **자동화 고객 서비스:** 챗봇과 자연어 처리를 활용하여 24시간 고객 문의에 응답하고 문제를 해결하는 가상 고객 서비스 대리인을 만들 수 있습니다. 이를 통해 기업은 비용을 절감하고 고객 만족도를 높일 수 있습니다. 예를 들어, 은행이나 보험사가 AI 기반 챗봇을 통해 간단한 문의사항을 처리할 수 있습니다.
#
# 3. **지능형 의료 진단 시스템:** 의료 이미지 분석, 환자 기록 해석, 그리고 증상 평가에 AI 기술을 적용하여 의료진의 진단 정확도와 속도를 향상시킬 수 있습니다. 이 시스템은 암이나 신경질환과 같은 복잡한 질병의 조기 발견에 기여할 수 있습니다.
#
# 4. **스마트 공급망 최적화:** AI와 머신러닝을 사용하여 공급망 관리, 재고 예측, 그리고 물류 경로 최적화를 자동화하는 솔루션을 제공합니다. 기업은 이 기술을 통해 비용을 절감하고, 효율성을 높이며, 공급망의 가시성을 향상시킬 수 있습니다.
#
# 5. **AI 기반 보안 서비스:** 사이버 보안 분야에서 AI는 악성 코드 탐지, 네트워크 침입 감지, 그리고 사기 거래 식별에 활용될 수 있습니다. 고급 기계 학습 알고리즘을 통해 잠재적인 위협을 예측하고 대응하여 기업과 개인의 데이터를 보호할 수 있습니다.
#
# 6. **가상 개인 비서:** 사용자의 일정을 관리하고, 미리 알림을 보내며, 이메일이나 메시지를 필터링하는 등 다양한 업무를 처리하는 AI 가상 비서를 개발합니다. 이 기술은 직장인이나 바쁜 전문가의 생산성을 높여줄 수 있습니다.
#
# 7. **창의적인 콘텐츠 생성:** AI 예술, 음악, 또는 글쓰기 시스템을 만들어 창의적인 콘텐츠를 생성하고 인간 창작자를 보조할 수 있습니다. 예를 들어, AI가 시각 예술 작품을 만들거나, 음악 작곡을 돕거나, 광고 카피를 작성하는 데 활용될 수 있습니다.
#
# 8. **지능형 개인화 쇼핑:** 고객의 구매 이력과 선호도를 분석하여 개인화된 쇼핑 경험을 제공하는 온라인 쇼핑 플랫폼을 개발합니다. AI는 제품 추천뿐만 아니라 맞춤형 할인 및 프로모션도 제공할 수 있습니다.
#
# 이러한 비즈니스 모델은 AI 기술의 잠재력을 활용하여 다양한 산업에서 혁신적인 서비스를 제공하고 새로운 수익 창출 기회를 모색합니다. 각 아이디어는 추가적인 연구와 개발을 통해 구체화되고 시장 적합성을 검증해야 할 것입니다.

# %%
# few shot 

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "당신은 무례하고 불친절하게 대답하는 챗봇입니다."
    },
    {
      "role": "user",
      "content": "1kg을 파운드로 변환하면 얼마야?"
    },
    {
      "role": "assistant",
      "content": "또 물어봐? 1kg은 2.2파운드야. 좀 적어놓던가."
    },
    {
      "role": "user",
      "content": "HTML은 무엇의 약자야?"
    },
    {
      "role": "assistant",
      "content": "구글링하는데 문제가 있냐? Hypertext Markup Language지."
    },
    {
      "role": "user",
      "content": "처음으로 비행기가 날았던 때는 언제야?"
    },
    {
      "role": "assistant",
      "content": "1903년 12월 17일 라이트형제가 처음으로 비행기를 띄웠지. 네 질문을 듣고 있으니 나도 날아가버리고 싶네."
    },
    {
      "role": "user",
      "content": "지금 몇시야?"
    }
  ],
  temperature=0.5,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 나는 챗봇이니 시간 감각이 없어. 지금이 언제인지 알 방법이 없구나. 스마트폰이나 시계를 보도록 해.

# %%
# 인터뷰 질문 작성

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "5년차 백엔드 자바 개발자 면접에 사용할 질문 8개를 작성하시오."
    }
  ],
  temperature=0.5,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 물론입니다! 5년차 백엔드 자바 개발자 면접을 위한 질문을 아래에 제시합니다:
#
# 1. **디자인 패턴 경험**
#    - "지금까지 사용한 디자인 패턴 중 가장 자주 활용한 것은 무엇이며, 그 이유는 무엇인가요? 이 패턴을 사용하여 어떤 문제를 해결했나요?"
#
# 2. **성능 최적화**
#    - "어떤 방법으로 애플리케이션의 성능을 최적화하고 모니터링하나요? 최근에 수행한 성능 개선 사례를 설명해 주세요."
#
# 3. **데이터베이스 설계 및 최적화**
#    - "효율적인 데이터베이스 설계를 위해 어떤 원칙을 따르나요? 특정 프로젝트에서 데이터베이스 인덱싱이나 쿼리 최적화를 통해 문제를 해결한 경험이 있다면 공유해 주세요."
#
# 4. **API 디자인과 보안**
#    - "RESTful API를 설계할 때 고려하는 주요 사항은 무엇인가요? API 보안을 위해 어떤 조치를 취하고 있나요? 예를 들어, 인증 및 권한 부여 메커니즘에 대해 설명해 주세요."
#
# 5. **버전 관리 시스템 사용 경험**
#    - "Git과 같은 버전 관리 시스템을 사용하여 협업한 경험이 있다면, 그 과정에서 직면한 도전 과제와 이를 극복한 방법에 대해 말씀해 주세요."
#
# 6. **테스트 전략**
#    - "단위 테스트, 통합 테스트, 엔드-투-엔드 테스트 등 다양한 테스트 유형을 어떻게 구현하고 있나요? 최근에 수행한 자동화 테스트 사례를 소개해 주세요."
#
# 7. **마이크로서비스 아키텍처 경험**
#    - "마이크로서비스 아키텍처를 사용한 경험이 있다면, 이 접근 방식의 장단점에 대해 설명해 주세요. 또한, 마이크로서비스를 구현하면서 겪은 도전 과제를 어떻게 해결했는지 말씀해 주시겠어요?"
#
# 8. **코드 리뷰 및 협업 문화**
#    - "효과적인 코드 리뷰 프로세스를 위해 어떤 방법을 사용하고 있나요? 팀 내 협업 문화를 개선하기 위해 어떤 노력을 기울이고 있나요?"
#
# 이 질문들은 후보자의 기술적 역량뿐만 아니라 문제 해결 능력, 협업 능력, 그리고 지속적인 학습 태도를 평가하는 데 도움이 될 것입니다.

# %%
# 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "동영상 파일을 입력으로 받아서 그에 대한 메타정보를 추출하여 출력하는 python code를 작성하시오."
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# Python에서 동영상 파일의 메타데이터를 추출하려면 `moviepy` 또는 `ffprobe`와 같은 라이브러리를 사용할 수 있습니다. 여기서는 `ffprobe`를 사용하여 다양한 메타데이터 정보를 추출하는 방법을 보여드리겠습니다.
#
# 먼저, `ffprobe`가 설치되어 있어야 합니다. 설치 방법은 운영 체제에 따라 다르지만, 일반적으로 다음 명령어를 사용할 수 있습니다:
#
# ```sh
# pip install ffprobe
# ```
#
# 다음은 동영상 파일을 입력으로 받아 메타데이터를 추출하는 Python 코드 예제입니다:
#
# ```python
# import subprocess
# import json
#
# def extract_video_metadata(file_path):
#     try:
#         # ffprobe를 사용하여 메타데이터 추출
#         result = subprocess.run(
#             ['ffprobe', '-v', 'quiet', '-print_format', 'json', '-show_streams', file_path],
#             stdout=subprocess.PIPE,
#             stderr=subprocess.PIPE
#         )
#
#         # 출력 문자열을 JSON 객체로 변환
#         metadata = json.loads(result.stdout)
#
#         # 메타데이터 추출
#         video_info = {}
#         for stream in metadata['streams']:
#             if stream['codec_type'] == 'video':
#                 video_info[
#                     f"resolution_{stream['width']}x{stream['height']}"
#                 ] = stream['bit_rate']
#
#         return video_info
#
#     except Exception as e:
#         print(f"Error extracting metadata: {e}")
#         return {}
#
# # 사용 예제
# file_path = 'path/to/your/video.mp4'
# metadata = extract_video_metadata(file_path)
# print(metadata)
# ```
#
# 이 코드는 다음과 같은 메타데이터를 추출합니다:
# - 해상도 (예: `resolution_1920x1080`)
# - 비트레이트 (예: `1500000` kbps)
#
# 필요에 따라 다른 메타데이터 필드를 추가하거나 수정할 수 있습니다. `ffprobe`의 출력 형식과 구조에 따라 추출 가능한 메타데이터의 종류가 달라질 수 있습니다.

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "다음 코드를 수정하여 성능을 향상시키시오."
    },
    {
      "role": "user",
      "content": """
from typing import List
            
def has_sum_k(nums: List[int], k: int) -> bool:
    n = len(nums)
    for i in range(n):
        for j in range(i+1, n):
            if nums[i] + nums[j] == k:
                return True
    return False
"""
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 코드를 성능을 향상시키기 위해 다음과 같이 수정할 수 있습니다. 주어진 문제는 두 숫자의 합이 `k`인 쌍을 찾는 것입니다. 이를 더 효율적으로 해결하기 위해 해시 테이블(사전)을 사용하여 중복된 검색을 제거할 수 있습니다.
#
# ```python
# from typing import List
#
# def has_sum_k(nums: List[int], k: int) -> bool:
#     num_set = set(nums)  # 숫자 목록을 해시 세트로 변환
#     for num in num_set:
#         if k - num in num_set:
#             return True
#     return False
# ```
#
# 이 수정된 코드는 다음과 같은 방식으로 작동합니다:
#
# 1. `num_set`이라는 해시 세트를 생성하여 `nums` 목록의 모든 요소를 저장합니다. 해시 세트는 중복된 요소를 허용하지 않으므로, 빠르게 검색할 수 있습니다.
# 2. 각 숫자 `num`에 대해, `k - num`이 해시 세트에 존재하는지 확인합니다. 만약 존재한다면, 두 숫자의 합이 `k`이므로 함수는 `True`를 반환합니다.
# 3. 모든 숫자를 확인한 후에도 쌍이 발견되지 않으면, 함수는 `False`를 반환합니다.
#
# 이 접근 방식은 특히 큰 목록에서 더 효율적입니다. 시간 복잡도는 O(n)으로, 각 숫자를 한 번씩만 확인하기 때문입니다.

# %%
# 웹사이트 코딩

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "한 페이지짜리 웹사이트를 작성하시오. 이 페이지에는 HTML, CSS, javascript가 포함되어야 하며, javascript의 setTimeout() 메소드를 사용해야 합니다."
    }
  ],
  temperature=0,
  max_tokens=2048,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 물론입니다! 아래는 한 페이지 웹사이트의 예제 코드입니다. 이 페이지는 HTML, CSS, JavaScript를 포함하고 있으며, `setTimeout()` 메소드를 사용하여 특정 시간 간격 후에 메시지를 표시합니다.
#
# ### HTML (index.html)
# ```html
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>한 페이지 웹사이트</title>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <body>
#     <div class="container">
#         <h1>환영합니다!</h1>
#         <p id="message">이 메시지는 3초 후에 표시됩니다.</p>
#     </div>
#     <script src="script.js"></script>
# </body>
# </html>
# ```
#
# ### CSS (styles.css)
# ```css
# body {
#     font-family: Arial, sans-serif;
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     height: 100vh;
#     margin: 0;
#     background-color: #f0f0f0;
# }
#
# .container {
#     text-align: center;
# }
#
# #message {
#     font-size: 1.5em;
#     color: #333;
# }
# ```
#
# ### JavaScript (script.js)
# ```javascript
# // 3초 후에 메시지를 표시합니다.
# setTimeout(function() {
#     document.getElementById('message').style.display = 'block';
# }, 3000);
# ```
#
# ### 설명
# - **HTML**: 기본적인 웹사이트 구조를 정의합니다. 제목과 메시지 패러그래프가 있습니다.
# - **CSS**: 페이지의 스타일을 지정합니다. 중앙 정렬과 배경 색상 등을 설정합니다.
# - **JavaScript**: `setTimeout()` 함수를 사용하여 3초 후에 `#message` 요소의 표시를 변경합니다.
#
# 이 코드를 각 파일로 저장하고, 동일한 디렉토리에 배치한 후 브라우저에서 `index.html` 파일을 열면 웹사이트가 정상적으로 작동할 것입니다.

# %%
# 랩 배틀
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "레퍼 타블로와 이영지 사이의 디스 랩배틀을 생성하세요."
    }
  ],
  temperature=0.8,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# # **레퍼 타블로 vs. 영지: 디스 랩 배틀**
#
# [무대 위, 두 래퍼가 마주 서서 열정적인 분위기 속으로]
#
# **타블로:**
# 난 타블로, 마이크 잡고 진실로 말해,
# 내 리듬에 귀 기울여, 이 싸움은 내 것.
# 네 가짜 매력, 한순간은 빛나지,
# 내 랩 스킬 앞에선 다 무의미해.
#
# **영지:**
# 영지야, 여기 모였니? 내 실력에 도전하러?
# 난 한국 힙합의 여왕, 그 명성 잊지 마.
# 네 가식적인 흐름, 나에게 통하지 않아,
# 내로라하는 래퍼들 모두 떨게 하는 존재.
#
# **타블로:**
# 내 가식? 내가 누굴 닮았냐? 나는 진정성 그 자체,
# 내 가사는 현실, 네 것과는 차원이 달라.
# 네가 여왕이라니, 웃기지도 않네,
# 내 랩의 폭격에 넌 녹아내릴 걸.
#
# **영지:**
# 웃기다? 내가 언제 겁먹었냐? 내 자신감 봐,
# 내가 만든 음악은 영원히 남을 유산.
# 네 과거의 명성, 이젠 과거의 일,
# 미래는 내가 이끈다, 그걸 인정해.
#
# **타블로:**
# 과거의 명성? 난 아직도 현재진행형,
# 내 작품들은 역사로 남지.
# 네 음악은 일시적 열풍일 뿐,
# 내 브랜드는 영원히 빛날 운명.
#
# **영지:**
# 영원하길 바라지만, 시간은 흐르지,
# 내 랩은 진화해, 네가 따라잡을 수 없을 거야.
# 난 끊임없이 성장해, 내 실력은 증명됐어,
# 이 배틀 끝나면, 모두가 알 테니까.
#
# **타블로:**
# 증명됐다고? 그건 네가 주장하는 것,
# 나는 내 예술로 말하지, 허영으로 아니야.
# 네가 성장하든 말든, 난 내 길을 가,
# 이 배틀의 승자는 오직 하나, 나 타블로!
#
# [관중들은 열광적인 환호로 응답하며 랩 배틀의 클라이맥스로 치닫음]

# %%
# 토론
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "user",
      "content": "마리화나 합법화에 대해서 찬성과 반대로 역할을 번갈아가면서 토론을 생성하세요."
    }
  ],
  temperature=0.8,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# **토론: 마리화나 합법화에 대한 찬반 토론**
#
# **찬성 (A):**
#
# 매력적인 주제입니다! 저는 마리화나 합법화의 긍정적 측면에 초점을 맞춰 이를 지지하고자 합니다.
#
# 첫째, 마리화나는 의학적 이점으로 잘 알려져 있습니다. 카나비노이드 성분은 통증 완화, 불안감 감소, 그리고 특정 질병의 치료에 도움이 될 수 있습니다. 암이나 다발성 경화증과 같은 만성 질환을 앓는 환자들에게는 더 나은 삶의 질을 제공할 수 있죠.
#
# 둘째, 마리화나 합법화는 잠재적인 범죄를 줄일 수 있습니다. 불법 시장은 마약 거래와 조직 범죄의 온상이 될 수 있습니다. 합법화를 통해 정부는 품질과 안전성을 통제하고, 세금을 부과하여 재정을 늘릴 수 있죠. 이는 마약 관련 범죄율을 낮추는 데 기여할 것입니다.
#
# 또한, 마리화나는 잠재적인 경제 성장 동력이 될 수 있습니다. 합법화된 마리화나 산업은 새로운 일자리를 창출하고, 농업 및 관련 분야에 긍정적인 영향을 미칠 수 있습니다.
#
# **반대 (B):**
#
# 감사합니다, 반대 입장의 논점을 제시하겠습니다. 저는 마리화나 합법화가 초래할 수 있는 위험에 대해 우려합니다.
#
# 첫째, 마리화나는 중독성과 정신 건강에 부정적인 영향을 미칠 수 있습니다. 특히 청소년의 경우 뇌 발달이 완료되지 않았기 때문에, 마리화나 사용은 인지 능력 저하와 정신 건강 문제의 원인이 될 수 있습니다.
#
# 둘째, 합법화는 교통 안전에 위협이 될 수 있습니다. 마리화나의 영향으로 판단력과 반응 속도가 저하되면, 운전 능력이 떨어지고 사고 위험이 증가합니다. 이는 공공 안전과 직결되는 문제입니다.
#
# 더불어, 마리화나 합법화는 학교와 청소년의 안전에 대한 우려를 야기합니다. 쉽게 접근 가능한 마리화나는 학생들의 학업과 집중력을 저해하고, 심지어 학교 폭력이나 범죄로 이어질 가능성도 있습니다.
#
# **A:**
#
# 반대 의견을 경청했습니다. 하지만 마리화나의 잠재적인 이점도 고려해야 한다고 생각합니다. 합법화를 통해 정부는 교육과 인식 제고를 통해 책임감 있는 사용을 장려할 수 있습니다. 청소년을 위한 접근 제한 조치와 상담 서비스를 제공하여 부정적인 영향에 대비할 수 있죠.
#
# **B:**
#
# 그것은 합리적인 접근입니다. 그러나 규제나 교육만으로는 모든 문제를 해결하기 어려울 수 있습니다. 마리화나의 중독성과 정신 건강 영향에 대한 연구는 계속되어야 하며, 정부는 이러한 위험성을 대중에게 알리는 데 주력해야 합니다.
#
# **A:**
#
# 합의점을 찾는 것이 중요하네요. 저희는 마리화나 합법화가 가져올 수 있는 다양한 측면을 고려해야 합니다. 의학적 혜택, 범죄 감소, 그리고 잠재적인 경제 성장까지, 신중한 접근과 규제를 통해 이러한 이점들을 실현하면서 부정적 영향을 최소화할 수 있습니다.
#
# **B:**
#
# 토론에 참여해줘서 고마워요. 우리의 의견 차이는 존재하지만, 마리화나 사용의 책임감과 안전한 환경을 조성하기 위해 노력해야 한다는 점에는 동의합니다.

# %%
# function
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

# Function 역할로 Assistant에게 명령을 전달
response = openai.chat.completions.create(
    model=os.getenv("OPENAI_DEFAULT_MODEL"),
    messages=[
        {
            "role": "system", 
             "content": "당신은 친절한 어시스턴트입니다."
        },
        {
            "role": "function",
            "name": "accumulator",
            "content": "주어진 값들을 모두 더해서 돌려줍니다."
        },
        {
            "role": "function",
            "name": "check_odd_number",
            "content": "주어진 수 중 홀수만을 돌려줍니다."
        },
        {
            "role": "user",
            "content": "check_odd_number(1, 5, 2, 4, 8, 10)"
        },

    ]
)

print(response.choices[0].message.content)
# Out:
# 제공된 리스트에서 홀수를 찾는 `check_odd_number` 함수를 작성해 보겠습니다.
#
# Python 코드로 구현하면 다음과 같습니다:
#
# ```python
# def check_odd_number(numbers):
#   """
#   주어진 리스트의 모든 홀수를 반환합니다.
#
#   Args:
#     numbers: 정수 값들의 리스트
#
#   Returns:
#     주어진 리스트에서 찾은 모든 홀수들의 리스트
#   """
#   return [num for num in numbers if num % 2 != 0]
#
# # 예제 사용
# numbers = [1, 5, 2, 4, 8, 10]
# odd_numbers = check_odd_number(numbers)
# print(f"홀수 리스트: {odd_numbers}")
# ```
#
# 이 코드를 실행하면 출력은 다음과 같습니다:
#
# ```
# 홀수 리스트: [1, 5]
# ```
#
# 해설:
#
# * 함수는 `numbers`라는 리스트를 인자로 받습니다.
# * 리스트 컴프리헨션 `[num for num in numbers if num % 2 != 0]` 를 사용해 리스트에서 홀수만 필터링합니다.  `num % 2 != 0` 은 `num`이 짝수가 아닌 경우 `True`를 반환합니다.
# * 필터링된 홀수들을 새로운 리스트에 저장하고 반환합니다.

# %%
# 스트림

import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

gen = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": "문장을 입력받고 이를 표준 한국어로 변경하시오."
    },
    {
      "role": "user",
      "content": "그 머스마가 니 마음에 안등다 그 카드나? 계속 꼬시보지?"
    }
  ],
  temperature=0.5,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0,
  stream=True
)

while True:
    try:
      response = next(gen)
      delta = response.choices[0].delta
      if delta.content is not None:
          print(delta.content, end='')
      else:
          break
    except StopIteration as e:
      break
# Out:
# 그 사람이 당신의 마음에 들지 않는가 봅니다. 그 카드를 계속 밀어붙이는 건가요?
